# %% [markdown]
# #Deep Adversarial Subspace Clustering

# %% [markdown]
# ##Pseudocode

# %%
data = ... #set of multidimentional points
generator = Generator()
discriminator = Discriminator()

for epoch in n_epochs:
  generator.fit(data) #get subspaces and clusters
  fake_data = decoder.generate_fake() #generate fake samples based on current parameters

  encoder.fit(fake_data, resampled(data))

# %%
def affinity_matrix(sexpr_coefs):
  return 1/2 * (mod(affinity_matrix) + mod(affinity_matrix.T))

class Generator:
  class Encoder():
    def transform (data):
      ... #deep convolutional (for non-lineraity)

  class SelfExpression():
    def __init__(self):
      coeffinients = ...
    def transform(data):
      ...

  class Decoder():
    def transform(data):
      ... #deep convolutional

  class SamplingLayer():
    def __init__(self):
      ...
    def generate_samples(cluster_labels, data):
      ...
      return real_samples, fake_samples

  def __init__(self):
    self.encoder = Encoder()
    self.self_expression = SelfExpression()
    self.decoder = Decoder()
    self.sampling = SamplingLayer()

  def do():
    latent_data = self.encoder.transform(raw_data)
    subspaces = fit_subspaces(latent_data)

    self.self_expression.transform(latent_data)
    sexpr_coefs = self.self_expression.coefficients

    self.decoder.transform(latent_data*sexpr_coefs)

    aff_mtx = affinity_matrix(sexpr_coefs)
    cluster_labels = NCut(aff_mtx)
    
    real, fake = self.sampling.generate_samples(cluster_labels, data)

    
    learn()

  def NCut(affinity_matrix):
    ...
    return cluster_labels

  def sampling(cluster_labels, self_expression, random_vector):
    return real_data, fake_data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        
        loss_measure = #the measure below

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
generator = Generator()
discriminator = Discriminator()

train_data, test_data = ...

n_epochs = 100
for epoch in range(n_epochs):
  generator.fit(data)
  discriminator.fit(generator.samples)
  discriminator.result
